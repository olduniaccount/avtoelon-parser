# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
advertsDF = pd.read_csv('list.csv')
advertsDF.head(10)
# Out:
#         id          brand      name  year  price     Город Объем двигателя, л  \
# 0  1164702  Mercedes-Benz     S 600  1997  15500   Ташкент       3.2 (бензин)
# 1  1204658      Chevrolet    Spark,  2013   6000   Ташкент   1.3 (газ-бензин)
# 2  1158890      Chevrolet   Lacetti  2015   8700   Ташкент   1.6 (газ-бензин)
# 3  1173369      Chevrolet   Cobalt,  2019  10500   Ташкент                NaN
# 4  1121369      Chevrolet   Cobalt,  2013   7000   Ташкент       1.5 (бензин)
# 5  1142261  Mercedes-Benz     C 200  2004  13000   Ташкент         2 (бензин)
# 6  1196941      Chevrolet    Spark,  2018   7600   Ташкент       1.3 (бензин)
# 7  1199895      Chevrolet  Lacetti,  2015   9500   Алмалык   1.5 (газ-бензин)
# 8  1200510            Kia  Carnival  2008  12500  Наманган          2.7 (газ)
# 9  1186333          Ravon  Nexia R3  2017   8000   Ташкент       1.5 (бензин)
#
#      Кузов    Пробег Коробка передач            Цвет           Привод  \
# 0    седан  237000.0         автомат  мокрый асфальт    задний привод
# 1  хэтчбек   99000.0        механика           серый  передний привод
# 2    седан  154000.0         автомат           белый              NaN
# 3      NaN    9500.0         автомат             NaN              NaN
# 4    седан  150000.0        механика             NaN  передний привод
# 5     купе  175000.0       типтроник        бордовый    задний привод
# 6  хэтчбек   10085.0         автомат      коричневый  передний привод
# 7    седан  119600.0        механика  мокрый асфальт  передний привод
# 8  минивэн  250000.0         автомат        бордовый    задний привод
# 9    седан   59000.0        механика         дельфин  передний привод
#
#   Есть доставка
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN

# %%
advertsDF
# Out:
#            id          brand      name  year  price      Город  \
# 0     1164702  Mercedes-Benz     S 600  1997  15500    Ташкент
# 1     1204658      Chevrolet    Spark,  2013   6000    Ташкент
# 2     1158890      Chevrolet   Lacetti  2015   8700    Ташкент
# 3     1173369      Chevrolet   Cobalt,  2019  10500    Ташкент
# 4     1121369      Chevrolet   Cobalt,  2013   7000    Ташкент
# ...       ...            ...       ...   ...    ...        ...
# 1595  1207465      Chevrolet  Lacetti,  2020  11962      Нукус
# 1596  1207470      Chevrolet    Matiz,  2017   5000  Самарканд
# 1597  1207458  Mercedes-Benz     E 300  1992   3600     Бухара
# 1598  1207452         Daewoo      Tico  1997   1929     Ургенч
# 1599  1207449     ВАЗ (Lada)      2101  1978   1600      Навои
#
#      Объем двигателя, л    Кузов    Пробег Коробка передач            Цвет  \
# 0          3.2 (бензин)    седан  237000.0         автомат  мокрый асфальт
# 1      1.3 (газ-бензин)  хэтчбек   99000.0        механика           серый
# 2      1.6 (газ-бензин)    седан  154000.0         автомат           белый
# 3                   NaN      NaN    9500.0         автомат             NaN
# 4          1.5 (бензин)    седан  150000.0        механика             NaN
# ...                 ...      ...       ...             ...             ...
# 1595   1.8 (газ-бензин)    седан       NaN        механика             NaN
# 1596       0.8 (бензин)  хэтчбек   35000.0        механика           белый
# 1597                NaN      NaN       NaN        механика             NaN
# 1598                NaN      NaN  215000.0        механика             NaN
# 1599                NaN      NaN       NaN        механика             NaN
#
#                Привод Есть доставка
# 0       задний привод           NaN
# 1     передний привод           NaN
# 2                 NaN           NaN
# 3                 NaN           NaN
# 4     передний привод           NaN
# ...               ...           ...
# 1595  передний привод           NaN
# 1596  передний привод           NaN
# 1597              NaN           NaN
# 1598              NaN           NaN
# 1599              NaN           NaN
#
# [1600 rows x 13 columns]

# %%
brands = pd.unique(advertsDF['brand'])
print(f"Кол-во марки: {len(brands)}" )
print(brands)
# Out:
# Кол-во марки: 36
# ['Mercedes-Benz' 'Chevrolet' 'Kia' 'Ravon' 'ВАЗ (Lada)' 'Hyundai' 'Daewoo'
#  'Mazda' 'Opel' 'Toyota' 'Москвич' 'ГАЗ' 'ЗАЗ' 'Ford' 'Volvo' 'УАЗ'
#  'Citroen' 'Chana' 'Audi' 'Mini' 'Dong Feng' 'Mitsubishi' 'BMW' 'Peugeot'
#  'Nissan' 'Hafei' 'Renault' 'Pontiac' 'Lexus' 'ИЖ' 'Tofas' 'Lincoln' 'JAC'
#  'Changan' 'Jeep' 'Fiat']

# %%
brandsss = advertsDF['brand'].value_counts()
brandsss
# Out:
# Chevrolet        897
# ВАЗ (Lada)       243
# Daewoo           232
# ГАЗ               45
# Mercedes-Benz     28
# Москвич           24
# Ravon             19
# Hyundai           15
# Kia               14
# Ford              11
# BMW               11
# Toyota            11
# Opel               5
# Nissan             4
# Tofas              4
# Mazda              4
# Mitsubishi         4
# JAC                4
# Peugeot            3
# Changan            2
# Jeep               2
# Hafei              2
# Renault            2
# УАЗ                2
# Fiat               1
# Lexus              1
# Audi               1
# ИЖ                 1
# Mini               1
# Citroen            1
# ЗАЗ                1
# Volvo              1
# Pontiac            1
# Lincoln            1
# Chana              1
# Dong Feng          1
# Name: brand, dtype: int64

# %%
brandsss.plot.bar()

plt.show()

# %%
cities = pd.unique(advertsDF['Город'])
print(cities)
print(len(cities))
# Out:
# ['Ташкент' 'Алмалык' 'Наманган' 'Денау' 'Гулистан' 'Самарканд' 'Ургенч'
#  'Термез' 'Чирчик' 'Нукус' 'Джизак' 'Янгиарыкский район' 'Навои' 'Бекабад'
#  'Коканд' 'Баяутский район' 'Бухара' 'Ангрен' 'Чустский район'
#  'Кошкупырский район' 'Юкарычирчикский район' 'Музрабадский район'
#  'Яккабагский район' 'Кибрайский район' 'Хивинский район' 'Карши'
#  'Фергана' 'Булунгурский район' 'Андижан' 'Куйичирчикский район'
#  'Шахрисабз' 'Ханкинский район' 'Багатский район' 'Каршинский район'
#  'Амударьинский район' 'Шаватский район' 'Учкурганский район'
#  'Гурленский район' 'Ширин' 'Гиждуван' 'Дехканабадский район'
#  'Хазараспский район' 'Ургенчский район' 'Кегейлийский район'
#  'Гузарский район' 'Фаришский район' 'Каттакурганский район'
#  'Чимбайский район' 'Сарыасийский район' 'Чиракчинский район' 'Ахангаран'
#  'Гиждуванский район' 'Ташкентский район' 'Сайхунабадский район'
#  'Бостанлыкский район' 'Чиназ' 'Джаркурганский район' 'Багдадский район'
#  'Зангиатинский район' 'Юкаричирчикский район' 'Букинский район'
#  'Камашинский район' 'Элликкалинский район' 'Жондорский район'
#  'Шахрисабзский район' 'Маргилан' 'Кумкурганский район' 'г. Фергана'
#  'Беруни' 'Алтыарыкский район' 'Китабский район' 'Нарынский район'
#  'Паркентский район' 'Каракульский район' 'Янгиюль' 'Дустликский район'
#  'Мархаматский район' 'Миришкорский район' 'Аккурганский район'
#  'Балыкчинский район' 'Кызырыкский район' 'Зарафшан' 'Касанский район'
#  'Асакинский район' 'Нурафшон' 'Чартакский район' 'Касбийский район'
#  'Янгибазарский район' 'Ургутский район' 'Муборекский район'
#  'Турткульский район' 'Пскентский район' 'Янгиюльский район'
#  'Нурабадский район' 'Пайарыкский район' 'Ферганский район'
#  'Бухарский район' 'Каганский район' 'Ходжаабадский район'
#  'Бувайдинский район' 'Узбекистанский район' 'Бахмальский район'
#  'Уйчинский район' 'Акдарьинский район' 'Навбахорский район'
#  'Бахмалский район' 'Галлааральский район' 'Ромитанский район'
#  'Пахтачийский район' 'Канимехский район' 'Шурчинский район']
# 111

# %%
advertsDF['Город'].value_counts()
# Out:
# Ташкент               351
# Самарканд             279
# Бухара                155
# Нукус                 135
# Ургенч                106
#                      ...
# Дустликский район       1
# Бахмальский район       1
# Нурабадский район       1
# Алтыарыкский район      1
# Шурчинский район        1
# Name: Город, Length: 111, dtype: int64
